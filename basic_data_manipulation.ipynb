# %%
from nilearn import plotting
# Out:
# /home/rishav/.local/lib/python3.9/site-packages/nilearn/datasets/__init__.py:86: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
nifti_path = './Neurohacking_data-0.0/kirby21/visit_1/113/kirby21_visit_1_113_113-01-MPRAGE.nii.gz'

# %%
plotting.plot_glass_brain(nifti_path)

# %%
from nilearn import image
smoothed_img = image.smooth_img(nifti_path,fwhm=5)

# %%
plotting.plot_glass_brain(nifti_path,cmap='gray')

# %%
# plot anat image
plotting.plot_anat(smoothed_img)

# %%
#plotting actual image using plot_anat
plotting.plot_anat(nifti_path)

# %%
#using heatcolors 
plotting.plot_anat(nifti_path,cmap='hot')

# %%
type(nifti_path)
# Out:
# str

# %%
import nibabel as nib

# %%
img = nib.load(nifti_path)
img.shape
# Out:
# (170, 256, 256)

# %%
type(img)
# Out:
# nibabel.nifti1.Nifti1Image
